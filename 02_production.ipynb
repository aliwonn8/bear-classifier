# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader
for q in ['grizzly', 'black bear', 'teddy bear']:
    downloader.download(q, limit=50, output_dir='bears', adult_filter_off=True, force_replace=False, timeout=5)
# Out:
# Requirement already satisfied: bing-image-downloader in /opt/conda/envs/fastai/lib/python3.8/site-packages (1.1.1)
# [%] Downloading Images to /notebooks/clean/bears/grizzly
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://4.bp.blogspot.com/-2_RuGHXGm0Y/UQW3vwH37JI/AAAAAAAAEzc/Mt1seFmFrog/s1600/Grizzly-Bear-.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/95/33/ef/9533ef1cd9e5245520263afae033f77f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.thedailybeast.com/image/upload/v1492115392/articles/2016/03/19/we-re-putting-grizzlies-in-the-crosshairs/150821-peacock-grizzlies-tease_gxhyz8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/58/75/c7/5875c79a143860875c78099cd7a7de3f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://s3.wp.wsu.edu/uploads/sites/1996/2016/07/Grizzly-Grisly.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://s3-ca-central-1.amazonaws.com/staging.canadavacations.com/SE068_01rr-1024x675.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://1.bp.blogspot.com/-422rK0Kje1E/UQW3yELFQeI/AAAAAAAAEzs/Rcg4Gniz4rU/s1600/Grizzly-Bear-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://i.pinimg.com/originals/6a/cb/a1/6acba13497f4f45a8e3a2b49f05a5293.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://ww1.hdnux.com/photos/02/67/40/751628/3/920x920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://i.pinimg.com/originals/ed/5a/40/ed5a400e02bb00f19606104e5881a027.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://4.bp.blogspot.com/-6wR6mdwvdAc/UQW3xNZ1IvI/AAAAAAAAEzo/sZMxfwG2usU/w1200-h630-p-k-no-nu/Grizzly-Bear.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://small-talks.com/wp-content/uploads/2017/08/big-grizzly-bear-1600x1200-1140x855.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.sierraclub.org/sites/www.sierraclub.org/files/sierra/articles/big/Grizzly Sleeping.jpg
# [!] Issue getting: https://www.sierraclub.org/sites/www.sierraclub.org/files/sierra/articles/big/Grizzly Sleeping.jpg
# [!] Error:: URL can't contain control characters. '/sites/www.sierraclub.org/files/sierra/articles/big/Grizzly Sleeping.jpg' (found at least ' ')
# [%] Downloading Image #13 from http://truewestmagazine.com/wp-content/uploads/2017/02/grizzly-hugh-glass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://fusion.ddmcdn.com/kids/02_Adam-With-Claws.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from http://elelur.com/data_images/mammals/grizzly-bear/grizzly-bear-07.jpg
# [!] Issue getting: http://elelur.com/data_images/mammals/grizzly-bear/grizzly-bear-07.jpg
# [!] Error:: <urlopen error [Errno -3] Temporary failure in name resolution>
# [%] Downloading Image #15 from https://patch.com/img/cdn20/users/598175/20180615/043017/styles/raw/public/processed_images/grizzly_and_cubs-1529051362-9813.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://static01.nyt.com/images/2019/05/12/opinion/munro-standing-bear/munro-standing-bear-superJumbo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://cdn.audleytravel.com/-/-/79/238143036145107082018030132153175220164003117009.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https
.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://factorydirectcraft.com/pimages/20200518060530-259297/miniature_brown_flocked_teddy_bears_true_vintage.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://i.pinimg.com/originals/5c/44/56/5c44562d914ddc5efb5b9142dec53528.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://cdn8.bigcommerce.com/s-dee9d/images/stencil/700x900/products/407/3297/Cuddles_18-_I_love_you_teddy_bear-_purple-2__66494.1327376693.jpg?c=2
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://i.pinimg.com/originals/26/28/fa/2628faac0ab8899a2a7b7dfa54772dc4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://cdn1.bigcommerce.com/server1900/dee9d/images/stencil/700x900/products/409/3293/cuddles-_pink_-Teddy_bear_love_-18in_-1__15984.1327375259.jpg?c=2
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://n1.sdlcdn.com/imgs/f/9/u/3-Feet-lovely-teddy-bear-SDL150242526-1-67e3e.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://i.ebayimg.com/images/g/8fwAAOSwnolfc0hQ/s-l400.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://www.wheniscalendars.com/wp-content/uploads/2017/08/National-American-Teddy-Bear-Day.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://blog.grabon.in/wp-content/uploads/2016/02/teddy-1024x640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://www.rd.com/wp-content/uploads/2020/02/GettyImages-1050600824.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://i.etsystatic.com/6554026/r/il/d0ec6e/276707496/il_fullxfull.276707496.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://i.pinimg.com/originals/28/38/a4/2838a457121d024a1d246d9b5b892cf9.png
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://i.barkpost.com/wp-content/uploads/2016/04/feat-1.jpg?q=70&amp;fit=crop&amp;crop=entropy&amp;w=808&amp;h=500
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://i.pinimg.com/736x/48/7f/9c/487f9c9260e1a10c1256be24d9d1321c--teddy-bears-picnic-shabby.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://factorydirectcraft.com/pimages/20191016120309-959943/micro_mini_white_teddy_bear_true_vintage.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #50 from https://i.pinimg.com/originals/2f/61/be/2f61be86262cc4befedcd956def03e66.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 50 images.
# ===============================================
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ===============================================

# %%
#hide
ims = ['http://4.bp.blogspot.com/-2_RuGHXGm0Y/UQW3vwH37JI/AAAAAAAAEzc/Mt1seFmFrog/s1600/Grizzly-Bear-.jpg']

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128 at 0x7FC534EDB580>

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#150) [Path('bears/grizzly/Image_32.jpg'),Path('bears/grizzly/Image_30.jpg'),Path('bears/grizzly/Image_43.jpg'),Path('bears/grizzly/Image_29.jpg'),Path('bears/grizzly/Image_2.jpg'),Path('bears/grizzly/Image_31.jpg'),Path('bears/grizzly/Image_35.jpg'),Path('bears/grizzly/Image_5.jpg'),Path('bears/grizzly/Image_36.jpg'),Path('bears/grizzly/Image_48.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.229972</td>
#       <td>2.089687</td>
#       <td>0.666667</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.155140</td>
#       <td>1.415699</td>
#       <td>0.566667</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.951703</td>
#       <td>0.439703</td>
#       <td>0.266667</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.582692</td>
#       <td>0.231608</td>
#       <td>0.033333</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.326118</td>
#       <td>0.192701</td>
#       <td>0.066667</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('black bear', 'grizzly', 'teddy bear'), value='black bear'), Dropdown(options…

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %%
learner.export
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8f12ca90d46f> in <module>
# ----> 1 learner.export
#
# NameError: name 'learner' is not defined

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
learn.save("trained_model")
# Out:
# Path('models/trained_model.pth')

# %%
learn = cnn_learner(data, models.resnet18).load('trained_model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-40a99e89bb35> in <module>
# ----> 1 learn = cnn_learner(data, models.resnet18).load('trained_model')
#
# NameError: name 'data' is not defined

# %%
learn.export('trained_model.pkl')

# %%
def no_tfms(self, x): return x
EmptyLabel.apply_tfms = no_tfms
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ef881c1571ec> in <module>
#       1 def no_tfms(self, x): return x
# ----> 2 EmptyLabel.apply_tfms = no_tfms
#
# NameError: name 'EmptyLabel' is not defined

# %%
learn = load_learner(path)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-34-0630b28aa292> in <module>
# ----> 1 learn = load_learner(path)
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/fastai/learner.py in load_learner(fname, cpu)
#     549     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     550     distrib_barrier()
# --> 551     res = torch.load(fname, map_location='cpu' if cpu else None)
#     552     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     553     if cpu: res.dls.cpu()
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# IsADirectoryError: [Errno 21] Is a directory: 'bears'

# %%
learn = load_learner(path, 'trained_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-33-056121ad4214> in <module>
# ----> 1 learn = load_learner(path, 'trained_model.pkl')
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/fastai/learner.py in load_learner(fname, cpu)
#     549     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     550     distrib_barrier()
# --> 551     res = torch.load(fname, map_location='cpu' if cpu else None)
#     552     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     553     if cpu: res.dls.cpu()
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# IsADirectoryError: [Errno 21] Is a directory: 'bears'

# %%
learner = load_learner

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#2) [Path('trained_model.pkl'),Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# ('grizzly', TensorImage(1), TensorImage([6.2070e-04, 9.9932e-01, 5.4454e-05]))

# %%
learn_inf.dls.vocab
# Out:
# ['black bear', 'grizzly', 'teddy bear']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9993')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.2.11-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 20.8 MB/s eta 0:00:01
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 42.0 MB/s eta 0:00:01
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.10.2-py3-none-any.whl (392 kB)
#      |████████████████████████████████| 392 kB 35.6 MB/s eta 0:00:01
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (6.1.7)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: bleach in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (3.2.1)
# Requirement already satisfied: nbformat>=4.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (5.0.8)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.11.2)
# Requirement already satisfied: traitlets>=5.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (5.0.5)
# Requirement already satisfied: jupyter-core in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (4.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: testpath in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: defusedxml in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.1.0)
# Requirement already satisfied: tornado>=6.1.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (6.1)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.3.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 7.9 MB/s  eta 0:00:01
# Collecting websocket-client
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 3.7 MB/s  eta 0:00:01
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.0)
# Collecting requests-unixsocket
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.0.0)
# Requirement already satisfied: Send2Trash in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.3)
# Requirement already satisfied: async-generator in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: webencodings in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (1.15.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert<7,>=6.0.0->voila) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.3)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests>=1.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2.25.0)
# Requirement already satisfied: urllib3>=1.8 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (1.25.11)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /opt/conda/envs/fastai/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (0.17.3)
# Requirement already satisfied: setuptools in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (49.6.0.post20201009)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (20.3.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/fastai/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (3.0.4)
# Installing collected packages: nbconvert, sniffio, anyio, websocket-client, requests-unixsocket, jupyter-server, voila
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# nbdev 1.1.5 requires nbconvert<6, but you'll have nbconvert 6.1.0 which is incompatible.
# Successfully installed anyio-3.3.0 jupyter-server-1.10.2 nbconvert-6.1.0 requests-unixsocket-0.2.0 sniffio-1.2.0 voila-0.2.11 websocket-client-1.2.1
# Enabling: voila
# - Writing config: /opt/conda/envs/fastai/etc/jupyter
#     - Validating...
#       voila 0.2.11 OK

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
